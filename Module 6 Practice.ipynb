# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Barbara Youngkeit\Desktop\SQL\CSV\laptops.csv")

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches screen_resolution  has_ips_panel  is_touchscreen  \
# 0     NaN  Ultrabook    13.3               NaN              1               0
#
#    resolution_width  resolution_height cpu_brand cpu_name  cpu_speed  Ram  \
# 0            1600.0               2560     Intel  Core i5        2.3  8.0
#
#   memory_type  primary_storage gpu_brand                 gpu_name OpSys  \
# 0         SSD              128     Intel   Iris Plus Graphics 640   NaN
#
#    Weight  Price  total_pixels
# 0     1.4  71379       4096000

# %%
df.shape
# Out:
# (1322, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1189 non-null   object
#  1   TypeName           1322 non-null   object
#  2   Inches             1322 non-null   float64
#  3   screen_resolution  930 non-null    object
#  4   has_ips_panel      1322 non-null   int64
#  5   is_touchscreen     1322 non-null   int64
#  6   resolution_width   1216 non-null   float64
#  7   resolution_height  1322 non-null   int64
#  8   cpu_brand          1322 non-null   object
#  9   cpu_name           1322 non-null   object
#  10  cpu_speed          1322 non-null   float64
#  11  Ram                1243 non-null   float64
#  12  memory_type        390 non-null    object
#  13  primary_storage    1322 non-null   int64
#  14  gpu_brand          1322 non-null   object
#  15  gpu_name           1322 non-null   object
# ...

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (193, 20)

# %%
df = pd.read_csv(r"C:\Users\Barbara Youngkeit\Desktop\SQL\CSV\laptops.csv")

# %%
df.shape
# Out:
# (1322, 20)

# %%
df.describe()
# Out:
#             Inches  has_ips_panel  is_touchscreen  resolution_width  \
# count  1322.000000    1322.000000     1322.000000       1216.000000
# mean     15.122542       0.281392        0.146747       1074.299342
# std       1.945084       0.449848        0.353988        286.711732
# min      10.100000       0.000000        0.000000        768.000000
# 25%      14.000000       0.000000        0.000000        900.000000
# 50%      15.600000       0.000000        0.000000       1080.000000
# 75%      15.600000       1.000000        0.000000       1080.000000
# max      35.600000       1.000000        1.000000       2160.000000
#
#        resolution_height    cpu_speed          Ram  primary_storage  \
# count        1322.000000  1322.000000  1243.000000      1322.000000
# mean         1895.639939     2.301664     9.198713       396.865356
# std           494.741031     0.507130     7.031441       419.775480
# min          1366.000000     0.900000     1.000000     -2048.000000
# ...

# %%
df.loc[df['primary_storage'] < 0, 'primary_storage'] *= -1
df.loc[df['Price'] < 0, 'Price'] *= -1

# %%
df.describe()
# Out:
#             Inches  has_ips_panel  is_touchscreen  resolution_width  \
# count  1322.000000    1322.000000     1322.000000       1216.000000
# mean     15.122542       0.281392        0.146747       1074.299342
# std       1.945084       0.449848        0.353988        286.711732
# min      10.100000       0.000000        0.000000        768.000000
# 25%      14.000000       0.000000        0.000000        900.000000
# 50%      15.600000       0.000000        0.000000       1080.000000
# 75%      15.600000       1.000000        0.000000       1080.000000
# max      35.600000       1.000000        1.000000       2160.000000
#
#        resolution_height    cpu_speed          Ram  primary_storage  \
# count        1322.000000  1322.000000  1243.000000      1322.000000
# mean         1895.639939     2.301664     9.198713       447.582451
# std           494.741031     0.507130     7.031441       365.172689
# min          1366.000000     0.900000     1.000000         0.000000
# ...

# %%
df['resolution_width'] = df['resolution_width'].fillna(df['total_pixels'] / df['resolution_height'])

# %%
df.describe()
# Out:
#             Inches  has_ips_panel  is_touchscreen  resolution_width  \
# count  1322.000000    1322.000000     1322.000000       1322.000000
# mean     15.122542       0.281392        0.146747       1071.428139
# std       1.945084       0.449848        0.353988        284.746319
# min      10.100000       0.000000        0.000000        768.000000
# 25%      14.000000       0.000000        0.000000        900.000000
# 50%      15.600000       0.000000        0.000000       1080.000000
# 75%      15.600000       1.000000        0.000000       1080.000000
# max      35.600000       1.000000        1.000000       2160.000000
#
#        resolution_height    cpu_speed          Ram  primary_storage  \
# count        1322.000000  1322.000000  1243.000000      1322.000000
# mean         1895.639939     2.301664     9.198713       447.582451
# std           494.741031     0.507130     7.031441       365.172689
# min          1366.000000     0.900000     1.000000         0.000000
# ...

# %%
df.drop(columns=['memory_type'],inplace = True)

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches screen_resolution  has_ips_panel  is_touchscreen  \
# 0     NaN  Ultrabook    13.3               NaN              1               0
#
#    resolution_width  resolution_height cpu_brand cpu_name  cpu_speed  Ram  \
# 0            1600.0               2560     Intel  Core i5        2.3  8.0
#
#    primary_storage gpu_brand                 gpu_name OpSys  Weight  Price  \
# 0              128     Intel   Iris Plus Graphics 640   NaN     1.4  71379
#
#    total_pixels
# 0       4096000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1189 non-null   object
#  1   TypeName           1322 non-null   object
#  2   Inches             1322 non-null   float64
#  3   screen_resolution  930 non-null    object
#  4   has_ips_panel      1322 non-null   int64
#  5   is_touchscreen     1322 non-null   int64
#  6   resolution_width   1322 non-null   float64
#  7   resolution_height  1322 non-null   int64
#  8   cpu_brand          1322 non-null   object
#  9   cpu_name           1322 non-null   object
#  10  cpu_speed          1322 non-null   float64
#  11  Ram                1243 non-null   float64
#  12  primary_storage    1322 non-null   int64
#  13  gpu_brand          1322 non-null   object
#  14  gpu_name           1322 non-null   object
#  15  OpSys              1133 non-null   object
# ...

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (717, 19)

# %%
df['Company'].unique()
# Out:
# array(['Acer', 'Dell', 'Lenovo', 'HP', 'Chuwi', 'dell', 'asus', 'MSI',
#        'Asus', 'hp', 'acer', 'lenovo', 'msi', 'Huawei', 'Vero', 'Razer',
#        'Toshiba', 'toshiba', 'mediacom', 'Mediacom', 'samsung', 'LG',
#        'Samsung', 'razer', 'Xiaomi'], dtype=object)

# %%
df['Company'] = df['Company'].str.title()

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell        181
# Hp          163
# Lenovo      157
# Asus         84
# Msi          43
# Acer         35
# Toshiba      28
# Samsung       7
# Razer         6
# Mediacom      4
# Chuwi         2
# Huawei        2
# Vero          2
# Lg            2
# Xiaomi        1
# Name: count, dtype: int64

# %%
from scipy.stats import zscore
df['z_score'] = zscore(df['Price'])
outliers = df[abs(df['z_score']) > 3]
num_outliers = len(outliers)
num_outliers
# Out:
# 5

# %%
df_cleaned = df.drop_duplicates(subset=['Company', 'cpu_name', 'gpu_name', 'total_pixels', 'Ram'])
num_rows_left = len(df_cleaned)
num_rows_left
# Out:
# 376
